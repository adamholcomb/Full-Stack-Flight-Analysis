# %%
import http.client
import requests, json
import pandas as pd

conn = http.client.HTTPSConnection("skyscanner-skyscanner-flight-search-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "0577c9d754msh6a149580eb6ccffp1b7c56jsn2b2ab82bc33c"
    }

# %%
#  #Airports where we can fly from: houston
# source_array = {"HOUA-sky"} 

# # Our destination airports: 
# destination_array = {"JFK-sky", "LAX-sky", "DFW-sky", "DEN-sky"}

# ### ( Note that technically these are Python **sets** and not arrays.)

# # And to make our life easier
# rootURL = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/"

# %%
# airports = { }
# for destination in destination_array:
#     for source in source_array:
#         myurl = rootURL + originCountry + "/" + currancy + "/" + locale + "/" + source + "/"  + destination + "/" + "2021-09-23"
#         response = requests.request("GET", myurl, headers=headers)
#         temp = json.loads(response.text)
        
#         # This checks if we have a quote or there were no flights
#         if("Quotes" in temp):
#             for Places in temp["Places"]:
#                 # Add the airport in the dictionary.
#                 airports[Places["PlaceId"]] = Places["Name"] 
#             for Quotes in temp["Quotes"]:
#                 print("************")
#                 # print("%s --> to  -->%s" %(origin,destination))
#                 ori = Quotes["OutboundLeg"]["OriginId"]
#                 dest = Quotes["OutboundLeg"]["DestinationId"]
#                 # Look for Airports in the dictionary
#                 print("Journy:  %s  --> %s"%(airports[ori],airports[dest]))
#                 print("Price: %s EUR" %Quotes["MinPrice"])

# %%
# Origin airport:
origins = ["HOU-iata","JFK-iata","LAX-iata","DFW-iata","DEN-iata"]

# Destination airports: 
destinations = ["HOU-iata","JFK-iata","LAX-iata","DFW-iata","DEN-iata","ATL-iata","ORD-iata","CLT-iata","LAS-iata","PHX-iata","PCO-iata","SEA-iata","MIA-iata","FLL-iata","SFO-iata","EWR-iata","MSP-iata","DTW-iata","BOS-iata","SLC-iata","PHL-iata","BWI-iata","TPA-iata","SAN-iata","AMA-iata","IAD-iata","BNA-iata","ABQ-iata","PDX-iata","DSM-iata","MSY-iata","BIL-iata","FAR-iata","MAF-iata","LBB-iata","BTV-iata","ROA-iata","MKE-iata","MSN-iata","GRB-iata","CYS-iata","JAC-iata","ELP-iata","CRP-iata","BHM-iata","HSV-iata","TUS-iata","LIT-iata","FAT-iata","SMF-iata","GJT-iata","BDL-iata","EYW-iata","PFN-iata","BOI-iata","EVV-iata","AZO-iata","AUS-iata","SAT-iata","MAF-iata"]

# Enter date as YYYY-MM-DD:
date = "2021-09-23"

# Other parameters
currancy = "USD"
originCountry = "US"
locale = "en-US"
baseURL = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/"

# %%
airports = {}
flights = {}
listlist = []
from time import sleep

#print("From Houston:")

for destination in destinations:
    for origin in origins:
        #print(f'------From {origin}------')
        myurl = baseURL + originCountry + "/" + currancy + "/" + locale + "/" + origin + "/"  + destination + "/" + date
        response = requests.request("GET", myurl, headers=headers)
        results = json.loads(response.text)
        listlist.append(results)

    #     Check if there are no flights
        if("Quotes" in results):
            for Places in results["Places"]:
                # Add the airport in the dictionary.
                airports[Places["PlaceId"]] = Places["Name"] 
            for Quotes in results["Quotes"]:
                print("***************")
                ori = Quotes["OutboundLeg"]["OriginId"]
                dest = Quotes["OutboundLeg"]["DestinationId"]
                price = Quotes["MinPrice"]
                print(f"${price} USD |{airports[ori]}| {airports[dest]} ")
                flights[airports[dest]] = price
                sleep(2.5)
    #             print(airports)

#    print("-------------------------------")
#    print("DONE!")
#    print(f"{len(flights)} total results")
    # print(airportsb)
# Out:
# ***************
# $89 USD |New York John F. Kennedy| Houston George Bush Intercntl.
# ***************
# $60 USD |Los Angeles International| Houston George Bush Intercntl.
# ***************
# $116 USD |Dallas Fort Worth International| Houston George Bush Intercntl.
# ***************
# $16 USD |Denver International| Houston George Bush Intercntl.
# ***************
# $120 USD |Houston George Bush Intercntl.| New York John F. Kennedy
# ***************
# $218 USD |Houston George Bush Intercntl.| New York John F. Kennedy
# ***************
# $122 USD |Los Angeles International| New York John F. Kennedy
# ***************
# $139 USD |Los Angeles International| New York John F. Kennedy
# ***************
# $91 USD |Dallas Fort Worth International| New York John F. Kennedy
# ***************
# $97 USD |Denver International| New York John F. Kennedy
# ***************
# $40 USD |Houston George Bush Intercntl.| Los Angeles International
# ***************
# $132 USD |New York John F. Kennedy| Los Angeles International
# ***************
# $40 USD |Dallas Fort Worth International| Los Angeles International
# ***************
# $26 USD |Denver International| Los Angeles International
# ***************
# $106 USD |Houston George Bush Intercntl.| Dallas Fort Worth International
# ***************
# $112 USD |New York John F. Kennedy| Dallas Fort Worth International
# ***************
# $129 USD |New York John F. Kennedy| Dallas Fort Worth International
# ***************
# $40 USD |Los Angeles International| Dallas Fort Worth International
# ***************
# $49 USD |Denver International| Dallas Fort Worth International
# ***************
# $20 USD |Houston George Bush Intercntl.| Denver International
# ***************
# $25 USD |Los Angeles International| Denver International
# ***************
# $49 USD |Dallas Fort Worth International| Denver International
# ***************
# $28 USD |Houston George Bush Intercntl.| Atlanta Hartsfield-Jackson
# ***************
# $103 USD |New York John F. Kennedy| Atlanta Hartsfield-Jackson
# ***************
# $110 USD |New York John F. Kennedy| Atlanta Hartsfield-Jackson
# ***************
# $37 USD |Los Angeles International| Atlanta Hartsfield-Jackson
# ***************
# $59 USD |Los Angeles International| Atlanta Hartsfield-Jackson
# ***************
# $28 USD |Dallas Fort Worth International| Atlanta Hartsfield-Jackson
# ***************
# $32 USD |Denver International| Atlanta Hartsfield-Jackson
# ***************
# $47 USD |Houston George Bush Intercntl.| Chicago O'Hare International
# ***************
# $112 USD |New York John F. Kennedy| Chicago O'Hare International
# ***************
# $149 USD |New York John F. Kennedy| Chicago O'Hare International
# ***************
# $38 USD |Los Angeles International| Chicago O'Hare International
# ***************
# $57 USD |Los Angeles International| Chicago O'Hare International
# ***************
# $119 USD |Dallas Fort Worth International| Chicago O'Hare International
# ***************
# $46 USD |Denver International| Chicago O'Hare International
# ***************
# $55 USD |Houston George Bush Intercntl.| Charlotte Douglas
# ***************
# $110 USD |Houston George Bush Intercntl.| Charlotte Douglas
# ***************
# $103 USD |New York John F. Kennedy| Charlotte Douglas
# ***************
# $224 USD |New York John F. Kennedy| Washington Dulles
# ***************
# $108 USD |Los Angeles International| Washington Dulles
# ***************
# $151 USD |Los Angeles International| Washington Dulles
# ***************
# $93 USD |Dallas Fort Worth International| Washington Dulles
# ***************
# $106 USD |Denver International| Washington Dulles
# ***************
# $80 USD |Houston George Bush Intercntl.| Nashville
# ***************
# $136 USD |Houston George Bush Intercntl.| Nashville
# ***************
# $137 USD |New York John F. Kennedy| Nashville
# ***************
# $189 USD |New York John F. Kennedy| Nashville
# ***************
# $177 USD |Los Angeles International| Nashville
# ***************
# $39 USD |Dallas Fort Worth International| Nashville
# ***************
# $76 USD |Denver International| Nashville
# ***************
# $94 USD |Denver International| Nashville
# ***************
# $140 USD |New York John F. Kennedy| Albuquerque
# ***************
# $39 USD |Denver International| Albuquerque
# ***************
# $38 USD |Houston George Bush Intercntl.| Portland
# ***************
# $147 USD |Houston George Bush Intercntl.| Portland
# ***************
# $101 USD |New York John F. Kennedy| Portland
# ***************
# $50 USD |Los Angeles International| Portland
# ***************
# $80 USD |Los Angeles International| Portland
# ***************
# $119 USD |Dallas Fort Worth International| Portland
# ***************
# $41 USD |Denver International| Portland
# ***************
# $59 USD |Denver International| Des Moines
# ***************
# $42 USD |Houston George Bush Intercntl.| New Orleans Louis Armstrong
# ***************
# $135 USD |New York John F. Kennedy| New Orleans Louis Armstrong
# ***************
# $214 USD |New York John F. Kennedy| New Orleans Louis Armstrong
# ***************
# $35 USD |Los Angeles International| New Orleans Louis Armstrong
# ***************
# $31 USD |Dallas Fort Worth International| New Orleans Louis Armstrong
# ***************
# $40 USD |Denver International| New Orleans Louis Armstrong
# ***************
# $204 USD |Denver International| Burlington
# ***************
# $159 USD |Houston George Bush Intercntl.| Milwaukee General Mitchell
# ***************
# $161 USD |New York John F. Kennedy| Milwaukee General Mitchell
# ***************
# $60 USD |Los Angeles International| Milwaukee General Mitchell
# ***************
# $51 USD |Denver International| Milwaukee General Mitchell
# ***************
# $133 USD |Denver International| Madison
# ***************
# $209 USD |Denver International| Madison

# %%
dfdf = pd.json_normalize(listlist)
print(f"Total list length: {len(listlist)}")
# listlist[2]
# Out:
# Total list length: 300

# %%
where_my_airport = pd.read_csv("https://datahub.io/core/airport-codes/r/airport-codes.csv")
where_my_airport.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %%
flight_list = []
for flight in listlist:
    flight_dict = {}
    try:
#         flight_dict['orig_lat'] = my_google_results[airport]
        flight_dict['min_price_usd'] = flight['Quotes'][0]['MinPrice']
        flight_dict['origin_name'] = flight['Places'][0]['Name']
        flight_dict['origin_code'] = flight['Places'][0]['IataCode']
        flight_dict['dest_name'] =  flight['Places'][1]['Name']
        flight_dict['dest_code'] =  flight['Places'][1]['IataCode']
        flight_list.append(flight_dict)
    except:
        pass
flightflight = pd.DataFrame(flight_list)
print(len(flight_list))
flightflight
# Out:
# 129
#      min_price_usd                      origin_name origin_code  \
# 0               89   Houston George Bush Intercntl.         IAH
# 1               60   Houston George Bush Intercntl.         IAH
# 2              116  Dallas Fort Worth International         DFW
# 3               16             Denver International         DEN
# 4              120   Houston George Bush Intercntl.         IAH
# ..             ...                              ...         ...
# 124            159   Houston George Bush Intercntl.         IAH
# 125            161         New York John F. Kennedy         JFK
# 126             60        Los Angeles International         LAX
# 127             51             Denver International         DEN
# 128            133             Denver International         DEN
#
#                           dest_name dest_code
# 0          New York John F. Kennedy       JFK
# 1         Los Angeles International       LAX
# 2    Houston George Bush Intercntl.       IAH
# 3    Houston George Bush Intercntl.       IAH
# 4          New York John F. Kennedy       JFK
# ..                              ...       ...
# 124      Milwaukee General Mitchell       MKE
# 125      Milwaukee General Mitchell       MKE
# 126      Milwaukee General Mitchell       MKE
# 127      Milwaukee General Mitchell       MKE
# 128                         Madison       MSN
#
# [129 rows x 5 columns]

# %%
origin_group = flightflight.groupby('origin_name').nunique()
origin_group
# Out:
#                                  min_price_usd  origin_code  dest_name  \
# origin_name
# Albuquerque                                  2            1          2
# Amarillo International                       1            1          1
# Atlanta Hartsfield-Jackson                   4            1          5
# Boston Logan International                   5            1          5
# Burlington                                   1            1          1
# Charlotte Douglas                            4            1          4
# Dallas Fort Worth International             17            1         18
# Dallas Love Field                            2            1          1
# Denver International                        23            1         24
# Detroit Wayne County                         3            1          3
# Fort Lauderdale International                3            1          3
# Houston George Bush Intercntl.              14            1         15
# Las Vegas Mccarran                           1            1          1
# Los Angeles International                    9            1         12
# Nashville                                    5            1          5
# New York John F. Kennedy                    13            1         13
# New York Newark                              2            1          2
# Phoenix-Mesa Gateway                         1            1          1
# Washington Dulles                            3            1          3
#
#                                  dest_code
# origin_name
# Albuquerque                              2
# Amarillo International                   1
# Atlanta Hartsfield-Jackson               5
# Boston Logan International               5
# Burlington                               1
# Charlotte Douglas                        4
# Dallas Fort Worth International         18
# Dallas Love Field                        1
# Denver International                    24
# Detroit Wayne County                     3
# Fort Lauderdale International            3
# Houston George Bush Intercntl.          15
# Las Vegas Mccarran                       1
# Los Angeles International               12
# Nashville                                5
# New York John F. Kennedy                13
# New York Newark                          2
# Phoenix-Mesa Gateway                     1
# Washington Dulles                        3

# %%
print(airports)
airport_df = pd.DataFrame(airports)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
dfdf.count()
# Out:
# Quotes        49
# Carriers      49
# Places        49
# Currencies    49
# Routes        49
# errors         1
# message        8
# dtype: int64

# %%
print(f"{len(flights)} total results")
# Out:
# 25 total results

# %%
flights
# Out:
# {'Sacramento International': 125,
#  'Denver International': 20,
#  'Miami International': 99,
#  'Philadelphia International': 59,
#  'Seattle / Tacoma International': 109,
#  'San Diego International': 119,
#  'New Orleans Louis Armstrong': 42,
#  'New York Newark': 40,
#  'Milwaukee General Mitchell': 159,
#  'Washington Dulles': 152,
#  'Austin-Bergstrom': 118,
#  'Dallas Fort Worth International': 106,
#  'Fort Lauderdale International': 28,
#  'Minneapolis St Paul': 102,
#  'Charlotte Douglas': 110,
#  'Detroit Wayne County': 73,
#  'Tampa International': 60,
#  'Phoenix-Mesa Gateway': 37,
#  'Los Angeles International': 40,
#  'San Francisco International': 119,
#  'Boston Logan International': 158,
#  'Salt Lake City': 87,
#  'Portland': 147,
#  'Las Vegas Mccarran': 55,
#  'Nashville': 136}

# %%
flights_df = pd.DataFrame(flights, index =['a'])
flights_df = flights_df.transpose()
flights_df = flights_df.reset_index()
flights_df = flights_df.rename(columns={"index": "Destination", "a": "Cost USD"})
flights_df
# Out:
#                         Destination  Cost USD
# 0          Sacramento International       125
# 1              Denver International        20
# 2               Miami International        99
# 3        Philadelphia International        59
# 4    Seattle / Tacoma International       109
# 5           San Diego International       119
# 6       New Orleans Louis Armstrong        42
# 7                   New York Newark        40
# 8        Milwaukee General Mitchell       159
# 9                 Washington Dulles       152
# 10                 Austin-Bergstrom       118
# 11  Dallas Fort Worth International       106
# 12    Fort Lauderdale International        28
# 13              Minneapolis St Paul       102
# 14                Charlotte Douglas       110
# 15             Detroit Wayne County        73
# 16              Tampa International        60
# 17             Phoenix-Mesa Gateway        37
# 18        Los Angeles International        40
# 19      San Francisco International       119
# 20       Boston Logan International       158
# 21                   Salt Lake City        87
# 22                         Portland       147
# 23               Las Vegas Mccarran        55
# 24                        Nashville       136

# %% [markdown]
# ### Destination
# [x] Make data
# * still needs lat, lon (reverse geocoder, or just cheat and google it...)
#
# #### Cost
#
# * Filter for min
# * or just do a range?
#
# ### pd.to_sql(name="dbdb", index=false, con = conn)
#
# ### Flask API
#
# * query db, jsonify, profit
# * you can cheat here and just feed in a json of your choice instead of querying the database while you get the database going...
#
#
# ### Put on map :smile:

# %%
import time, datetime, dateutil
import pandas as pd
import requests

# Origin airport:
origin = "HOUA-sky" 

# Destination airports: 
single_dest = "JFK-iata"

# Enter date as YYYY-MM-DD:
source_begin_date = "2021-09-06"
source_end_date =  "2021-10-03"  
daterange = pd.date_range(source_begin_date, source_end_date)

# Other parameters
currancy = "USD"
originCountry = "US"
locale = "en-US"
baseURL = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/"

# %%
calendar = {}

print("From: Houston")

for single_date in daterange:
    myurl = baseURL + originCountry + "/" + currancy + "/" + locale + "/" + origin + "/"  + single_dest + "/" + "2021-09-06"
    response = requests.request("GET", myurl, headers=headers)
    results = json.loads(response.text)
        
    # Check if there are no flights
    if("Quotes" in results):
        for Places in results["Places"]:
            # Add the airport in the dictionary.
            airports[Places["PlaceId"]] = Places["Name"] 
        for Quotes in results["Quotes"]:
            print("***************")
            print(single_date.strftime("%d-%b %a"))
            ori = Quotes["OutboundLeg"]["OriginId"]
            dest = Quotes["OutboundLeg"]["DestinationId"]
            price = Quotes["MinPrice"]
            print(f"${price} USD | {airports[dest]} ")
            calendar[single_date.strftime("%d-%b %a")] = price

print("-------------------------------")
print("DONE!")
print(f"{len(calendar)} total results")
# $329 USD | New York John F. Kennedy
# ***************
# 28-Sep Tue
# $110 USD | New York John F. Kennedy
# ***************
# 28-Sep Tue
# $329 USD | New York John F. Kennedy
# ***************
# 29-Sep Wed
# $110 USD | New York John F. Kennedy
# ***************
# 29-Sep Wed
# $329 USD | New York John F. Kennedy
# ***************
# 30-Sep Thu
# $110 USD | New York John F. Kennedy
# ***************
# 30-Sep Thu
# $329 USD | New York John F. Kennedy
# ***************
# 01-Oct Fri
# $110 USD | New York John F. Kennedy
# ***************
# 01-Oct Fri
# $329 USD | New York John F. Kennedy
# ***************
# 02-Oct Sat
# $110 USD | New York John F. Kennedy
# ***************
# 02-Oct Sat
# $329 USD | New York John F. Kennedy
# ***************
# 03-Oct Sun
# $110 USD | New York John F. Kennedy
# ***************
# 03-Oct Sun
# $329 USD | New York John F. Kennedy
# -------------------------------
# DONE!
# 28 total results

# %%
calendar
# Out:
# {'06-Sep Mon': 329,
#  '07-Sep Tue': 329,
#  '08-Sep Wed': 329,
#  '09-Sep Thu': 329,
#  '10-Sep Fri': 329,
#  '11-Sep Sat': 329,
#  '12-Sep Sun': 329,
#  '13-Sep Mon': 329,
#  '14-Sep Tue': 329,
#  '15-Sep Wed': 329,
#  '16-Sep Thu': 329,
#  '17-Sep Fri': 329,
#  '18-Sep Sat': 329,
#  '19-Sep Sun': 329,
#  '20-Sep Mon': 329,
#  '21-Sep Tue': 329,
#  '22-Sep Wed': 329,
#  '23-Sep Thu': 329,
#  '24-Sep Fri': 329,
#  '25-Sep Sat': 329,
#  '26-Sep Sun': 329,
#  '27-Sep Mon': 329,
#  '28-Sep Tue': 329,
#  '29-Sep Wed': 329,
#  '30-Sep Thu': 329,
#  '01-Oct Fri': 329,
#  '02-Oct Sat': 329,
#  '03-Oct Sun': 329}

# %%
cal_df = pd.DataFrame(calendar, index = ['a'])
cal_df = cal_df.transpose()
cal_df = cal_df.reset_index()
cal_df = cal_df.rename(columns={"index": "Date", "a": "Cost USD"})
cal_df
# Out:
#           Date  Cost USD
# 0   06-Sep Mon       329
# 1   07-Sep Tue       329
# 2   08-Sep Wed       329
# 3   09-Sep Thu       329
# 4   10-Sep Fri       329
# 5   11-Sep Sat       329
# 6   12-Sep Sun       329
# 7   13-Sep Mon       329
# 8   14-Sep Tue       329
# 9   15-Sep Wed       329
# 10  16-Sep Thu       329
# 11  17-Sep Fri       329
# 12  18-Sep Sat       329
# 13  19-Sep Sun       329
# 14  20-Sep Mon       329
# 15  21-Sep Tue       329
# 16  22-Sep Wed       329
# 17  23-Sep Thu       329
# 18  24-Sep Fri       329
# 19  25-Sep Sat       329
# 20  26-Sep Sun       329
# 21  27-Sep Mon       329
# 22  28-Sep Tue       329
# 23  29-Sep Wed       329
# 24  30-Sep Thu       329
# 25  01-Oct Fri       329
# 26  02-Oct Sat       329
# 27  03-Oct Sun       329

# %%
import time, datetime, dateutil
import pandas as pd

source_begin_date = "2021-09-06"
source_end_date =  "2021-10-03"  
daterange = pd.date_range(source_begin_date, source_end_date)
airports = { }
maxbudget = 400

# %%
class findingCheapestFlights:
    
    def __init__(self, originCountry = "DE", currency = "EUR", locale = "en-US", rootURL="https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"):
        self.currency = currency
        self.locale =  locale
        self.rootURL = rootURL
        self.originCountry = originCountry

    def setHeaders(self, headers):
        self.headers =  headers

    def browseQuotes(self, source, destination, date):
        quoteRequestPath = "/apiservices/browsequotes/v1.0/"
        browseQuotesURL = self.rootURL + quoteRequestPath + self.originCountry + "/" + self.currency + "/" + self.locale + "/" + source + "/" + destination + "/" + date.strftime("%Y-%m-%d")
        response = requests.request("GET", url = browseQuotesURL, headers = self.headers)
        resultJSON = json.loads(response.text)
        return resultJSON

# %%
import time
cheapest_flight_finder = findingCheapestFlights()
cheapest_flight_finder.setHeaders(headers)

total_compute_time = 0.0
total_request_time = 0.0

function_start = time.time()
for single_date in daterange:
    for destination in destination_array:
        for source in source_array:
            request_start = time.time()
            resultJSON = cheapest_flight_finder.browseQuotes(source, destination,single_date)
            request_end = time.time()
            if("Quotes" in resultJSON):
                for Places in resultJSON["Places"]:
                    # Add the airport in the dictionary.
                    airports[Places["PlaceId"]] = Places["Name"] 
                for Quotes in resultJSON["Quotes"]:
                    if(Quotes["MinPrice"]<maxbudget):                        
                        print("************")
                        print(single_date.strftime("%d-%b %a"))
                        # print("%s --> to  -->%s" %(origin,destination))
                        source = Quotes["OutboundLeg"]["OriginId"]
                        dest = Quotes["OutboundLeg"]["DestinationId"]
                        # Look for Airports in the dictionary
                        print("Journy:  %s  --> %s"%(airports[source],airports[dest]))
                        print("Price: %s EUR" %Quotes["MinPrice"])
            calculation_end = time.time()
            total_compute_time += calculation_end - request_end 
            total_request_time += request_end - request_start
print("\nBenchmark Stats :")
print("Time spent in computing: %f seconds"%total_compute_time )
print("Time spent in requesting: %f seconds"%total_request_time )
print("Time spent in program: %f seconds"%(time.time()-function_start))
# Out:
# ************
# 07-Sep Tue
# Journy:  Houston George Bush Intercntl.  --> London Luton
# Price: 306 EUR
# ************
# 07-Sep Tue
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 342 EUR
# ************
# 08-Sep Wed
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 08-Sep Wed
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 08-Sep Wed
# Journy:  Houston George Bush Intercntl.  --> London Heathrow
# Price: 306 EUR
# ************
# 12-Sep Sun
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 308 EUR
# ************
# 12-Sep Sun
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 308 EUR
# ************
# 13-Sep Mon
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 298 EUR
# ************
# 13-Sep Mon
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 298 EUR
# ************
# 13-Sep Mon
# Journy:  Houston George Bush Intercntl.  --> London Heathrow
# Price: 387 EUR
# ************
# 14-Sep Tue
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 14-Sep Tue
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 15-Sep Wed
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 15-Sep Wed
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 291 EUR
# ************
# 16-Sep Thu
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 292 EUR
# ************
# 16-Sep Thu
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 292 EUR
# ************
# 17-Sep Fri
# Journy:  Houston George Bush Intercntl.  --> London Stansted
# Price: 366 EUR
#
# Benchmark Stats :
# Time spent in computing: 0.002995 seconds
# Time spent in requesting: 33.480275 seconds
# Time spent in program: 33.485265 seconds
